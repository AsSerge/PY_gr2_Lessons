# %%
# импортируем Pandas  Numpy matplotlib.pyplot
# отключим предупреждения Anaconda
import warnings
warnings.simplefilter('ignore')
import pandas as pd
import numpy as np
# сделаем вывод графика, он будет сохранен в ноутбуке
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Устанавливаем точность в 2 знака после запятой

# %%
np.set_printoptions(precision=2)

# %% [markdown]
# Будем показывать основные методы Pandas, анализируя набор данных по оттоку клиентов телеком-оператора (файл beauty.csv).
# Для каждрого опрошенного имеется следующая информация: заработная плата за час работы ($), опыт работы (годы), образование(годы), внешняя привлекательность (в баллах от 1 до 5), бинарные признаки: пол, семейное положение, состояние здоровья (хорошее/плохое), членство в профсоюзе, цвет кожи (белый/чёрный), занятость в сфере обслуживания (да/нет).
# Прочитаем данные (метод read_csv) и посмотрим на первые 5 строк с помощью метода head. Данные заносятся в переменную data.

# %%
data = pd.read_csv('beauty.csv', sep=';')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Смотрим первые и лоследние 5 строк, определяем количество строк и столбцов.

# %%
data.head(10)
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  looks
# 0   5.73     30      0         1      0       1        1        1    14      4
# 1   4.28     28      0         1      0       1        1        0    12      3
# 2   7.96     35      0         1      0       1        0        0    10      4
# 3  11.57     38      0         1      0       0        1        1    16      3
# 4  11.42     27      0         1      0       0        1        0    16      3
# 5   3.91     20      0         0      0       1        1        0    12      3
# 6   8.76     12      0         1      0       0        1        0    16      3
# 7   7.69      5      1         1      0       0        0        0    16      4
# 8   5.00      5      0         1      0       1        0        0    16      3
# 9   3.89     12      0         1      0       1        0        0    12      3

# %%
data.shape
# Out:
# (1260, 10)

# %%
data.tail()
# Out:
#       wage  exper  union  goodhlth  black  female  married  service  educ  \
# 1255  1.61     25      0         1      1       1        0        1    12
# 1256  1.68      4      0         1      0       1        1        1    12
# 1257  3.29     35      0         1      1       1        0        1    12
# 1258  2.31     15      0         1      1       1        1        1    10
# 1259  1.92     24      0         0      0       1        0        1    16
#
#       looks
# 1255      3
# 1256      2
# 1257      3
# 1258      3
# 1259      3

# %% [markdown]
# Краткая статистика

# %%
data.info() # Краткая информация
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   wage      1260 non-null   float64
#  1   exper     1260 non-null   int64
#  2   union     1260 non-null   int64
#  3   goodhlth  1260 non-null   int64
#  4   black     1260 non-null   int64
#  5   female    1260 non-null   int64
#  6   married   1260 non-null   int64
#  7   service   1260 non-null   int64
#  8   educ      1260 non-null   int64
#  9   looks     1260 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 98.5 KB

# %%
data.describe() # Описательная статистика
# Out:
#               wage        exper        union     goodhlth        black  \
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      6.306690    18.206349     0.272222     0.933333     0.073810
# std       4.660639    11.963485     0.445280     0.249543     0.261564
# min       1.020000     0.000000     0.000000     0.000000     0.000000
# 25%       3.707500     8.000000     0.000000     1.000000     0.000000
# 50%       5.300000    15.000000     0.000000     1.000000     0.000000
# 75%       7.695000    27.000000     1.000000     1.000000     0.000000
# max      77.720000    48.000000     1.000000     1.000000     1.000000
#
#             female      married      service         educ        looks
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      0.346032     0.691270     0.273810    12.563492     3.185714
# std       0.475892     0.462153     0.446089     2.624489     0.684877
# ...

# %% [markdown]
# DataFrame можно отсортировать по значению какого-нибудь из признаков. В нашем случае, например, по размеру заработной платы

# %%
data.sort_values(by='wage', ascending = False).head(20) # Сортировка по столбцу wage, ascending - по возрастанию = Ложь
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 602   77.72      9      1         1      1       1        1        1    13
# 269   41.67     16      0         0      0       0        1        0    13
# 415   38.86     29      0         1      0       0        1        0    13
# 69    32.79     33      0         1      0       0        1        1    16
# 290   31.09     32      0         0      0       0        1        0    13
# 68    29.98     12      0         1      0       0        1        1    17
# 1113  26.24     37      0         1      0       0        1        0    12
# 1108  26.24     37      0         1      0       0        1        0    12
# 299   26.24     24      0         1      0       0        1        0    12
# 396   26.22     17      0         1      0       0        1        1    17
# 1044  25.64     13      0         1      0       0        1        0    10
# ...

# %%
data.sort_values(by=['female', 'wage'],
        ascending=[True, False]).head(10)
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 269   41.67     16      0         0      0       0        1        0    13
# 415   38.86     29      0         1      0       0        1        0    13
# 69    32.79     33      0         1      0       0        1        1    16
# 290   31.09     32      0         0      0       0        1        0    13
# 68    29.98     12      0         1      0       0        1        1    17
# 299   26.24     24      0         1      0       0        1        0    12
# 1108  26.24     37      0         1      0       0        1        0    12
# 1113  26.24     37      0         1      0       0        1        0    12
# 396   26.22     17      0         1      0       0        1        1    17
# 338   25.64     28      0         1      0       0        1        0    16
#
#       looks
# 269       4
# 415       3
# 69        4
# 290       3
# 68        3
# 299       3
# 1108      2
# 1113      3
# 396       3
# ...

# %% [markdown]
# Индексация и извлечение данных
# DataFrame можно индексировать по-разному. В связи с этим рассмотрим различные способы индексации и извлечения нужных нам данных из DataFrame на примере простых вопросов.
#
# Для извлечения отдельного столбца можно использовать конструкцию вида DataFrame['Name']. Воспользуемся этим для ответа на вопрос: какова доля людей с хорошим здоровьем среди опрошенных?

# %%
data['goodhlth'].mean() # Индексация по столбцу (mean - среднее значение)
# Out:
# 0.9333333333333333

# %% [markdown]
# Очень удобной является логическая индексация DataFrame по одному столбцу. Выглядит она следующим образом: df[P(df['Name'])], где P - это некоторое логическое условие, проверяемое для каждого элемента столбца Name. Итогом такой индексации является DataFrame, состоящий только из строк, удовлетворяющих условию P по столбцу Name. Воспользуемся этим для ответа на вопрос: какова средняя заработная плата среди женщин?

# %%
data[data['married'] == 1].head(10) #  Выбор только тех строк, которые соответствуют условию => итог НОВЫЙ DataFrame
# Out:
#      wage  exper  union  goodhlth  black  female  married  service  educ  \
# 0    5.73     30      0         1      0       1        1        1    14
# 1    4.28     28      0         1      0       1        1        0    12
# 3   11.57     38      0         1      0       0        1        1    16
# 4   11.42     27      0         1      0       0        1        0    16
# 5    3.91     20      0         0      0       1        1        0    12
# 6    8.76     12      0         1      0       0        1        0    16
# 11   4.03      6      0         1      0       0        1        0    16
# 12   5.14     19      0         1      0       0        1        1    17
# 14   7.99     12      0         1      0       0        1        0    16
# 15   6.01     17      0         1      0       0        1        0    16
#
#     looks
# 0       4
# 1       3
# 3       3
# 4       3
# 5       3
# 6       3
# 11      4
# 12      2
# 14      4
# 15      4

# %%
data[(data['goodhlth'] == 1) & (data['female'] == 1)].head() # Составное условие
# Out:
#    wage  exper  union  goodhlth  black  female  married  service  educ  looks
# 0  5.73     30      0         1      0       1        1        1    14      4
# 1  4.28     28      0         1      0       1        1        0    12      3
# 2  7.96     35      0         1      0       1        0        0    10      4
# 8  5.00      5      0         1      0       1        0        0    16      3
# 9  3.89     12      0         1      0       1        0        0    12      3

# %%
data[(data['female'] == 0)]['wage'].mean() - data[(data['female'] == 1)]['wage'].mean()

# data[(data['female'] == 0)]['wage'].mean()
# Out:
# 3.0694650173688434

# %% [markdown]
# Какова максимальная заработная плата среди мужчин, имеющих членство в профсоюзе, и с опытом работы до 10 лет?

# %%
data[(data['female'] == 0) & (data['union'] == 1) & (data['exper'] < 10)]['wage'].max()
# Out:
# 12.82

# %% [markdown]
# Применение функции к каждому столбцу

# %%
data.apply(np.mean)
# Out:
# wage         6.306690
# exper       18.206349
# union        0.272222
# goodhlth     0.933333
# black        0.073810
# female       0.346032
# married      0.691270
# service      0.273810
# educ        12.563492
# looks        3.185714
# dtype: float64

# %% [markdown]
# Группирование данных в зависимости от значения признака looks и подсчет среднего значения по каждому столбцу в каждой группе.

# %%
data['looks'].describe()
# Out:
# count    1260.000000
# mean        3.185714
# std         0.684877
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: looks, dtype: float64

# %%
g = data.groupby('looks') # Группируем данные по looks
for (i, sub_df) in g:
    print(sub_df['wage'].mean(), sub_df['looks'].mean())
# Out:
# 4.621538461538462 1.0
# 5.3288028169014074 2.0
# 6.504598337950138 3.0
# 6.299340659340659 4.0
# 7.388421052631578 5.0

# %% [markdown]
# Обращение к конкретной группе

# %%
d1 = g.get_group(2) # Обращаемся к конкретной группе - в данном случае к той, где 'looks' == 2
d1
# Out:
#       wage  exper  union  goodhlth  black  female  married  service  educ  \
# 12    5.14     19      0         1      0       0        1        1    17
# 33    8.17     18      0         1      0       0        1        0    16
# 35    9.62     37      0         1      0       0        1        0    13
# 37    7.69     10      1         1      0       0        1        0    13
# 57    6.56     17      0         1      0       0        1        0    13
# ...    ...    ...    ...       ...    ...     ...      ...      ...   ...
# 1225  5.82     20      0         1      0       1        0        1    17
# 1226  1.09      8      0         1      0       1        1        1    10
# 1236  4.81     31      0         1      0       0        1        0    12
# 1241  5.34     20      0         1      0       0        1        0    12
# 1256  1.68      4      0         1      0       1        1        1    12
#
#       looks
# 12        2
# 33        2
# 35        2
# 37        2
# ...

# %%
len(d1) # Получаем количество строк, что соответствует количеству включений. Это для решения первой задачи.
# Out:
# 142

# %% [markdown]
# Визуализация в Pandas
#
# Метод scatter_matrix позволяет визуализировать попарные зависимости между признаками (а также распределение каждого признака на диагонали). Проделаем это для небинарных признаков

# %%
pd.scatter_matrix(data[['wage', 'exper', 'educ', 'looks']], 
                  figsize=(15, 15), diagonal='kde')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-de7d54cdeeec> in <module>
# ----> 1 pd.scatter_matrix(data[['wage', 'exper', 'educ', 'looks']],
#       2                   figsize=(15, 15), diagonal='kde')
#       3 plt.show()
#
# d:\_python38-32\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'scatter_matrix'

# %% [markdown]
# Для каждого признака можно построить отдельную гистограмму

# %%
data['looks'].hist()

# %%
data.hist(color = 'k', bins = 30, figsize=(15,10))
plt.show()

# %% [markdown]
# Полезным также является график типа box plot ("ящик с усами"). Он позволяет компактно визуализировать основные характеристики (медиану, нижний и верхний квартили, минимальное и максимальное значение, выбросы) распределения признаков.

# %%
data.boxplot(column='exper', by='looks')
plt.show()

# %% [markdown]
# Можно сделать это, сгруппировав данные по какому-либо другому признаку

# %%
data.boxplot(column='exper',  by=['female', 'black'], 
           figsize=(10,10))
plt.show()
