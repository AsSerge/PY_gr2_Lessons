# %% [markdown]
# <p><strong>Дополнительное задание</strong></p>
# <p>Выполнил <strong>Цветков Сергей</strong></p>
# <p>В данном Датасете приведены сведения об абитуриентах, зачисленных на обучение в ВУЗ 1.</p>
# <ol>
# <li>Оцените представленный Датасет, разберитесь со смыслом представленных данных</li>
# <li>Очистите данные от незаполненных записей</li>
# <li>Проведите разведочный анализ данных</li>
# <li>Определите наиболее значимые факторы, определяющие поступление абитуриентов на факультет</li>
# <li>Постройте графики и диаграммы, характеризующие данные</li>
# </ol>

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

# %%
# Загружаем данные
# df = pd.read_csv('Statistika PRK.csv', sep=';')
data = pd.read_excel('Statistika PRK.xlsx', index_col = 'Идентификатор конкурса') # Установка индекса

# %%
# Оцениваем датасет
data.shape
print('Датасет состоит из {} строк и {} столбцов'.format(data.shape[0], data.shape[1]))
# Out:
# Датасет состоит из 16551 строк и 26 столбцов

# %%
data.head(15)
# Out:
#                        Пол        Дата рождения           Гражданство  \
# Идентификатор конкурса
# 1                        М  2001-05-24 00:00:00  Российская Федерация
# 2                        М  2001-05-24 00:00:00  Российская Федерация
# 3                        М  1988-09-16 00:00:00  Российская Федерация
# 4                        М  1988-09-16 00:00:00  Российская Федерация
# 5                        Ж  1993-09-08 00:00:00  Российская Федерация
# 6                        Ж  2000-06-21 00:00:00  Российская Федерация
# 7                        Ж  2000-06-21 00:00:00  Российская Федерация
# 8                        Ж  2000-06-21 00:00:00  Российская Федерация
# 9                        Ж  2000-06-21 00:00:00  Российская Федерация
# 10                       М  1997-05-20 00:00:00  Российская Федерация
# 11                       М  1997-05-20 00:00:00  Российская Федерация
# 12                       М  1999-01-29 00:00:00  Российская Федерация
# 13                       М  1999-01-29 00:00:00  Российская Федерация
# 14                       М  1993-01-03 00:00:00  Российская Федерация
# 15                       М  2001-01-28 00:00:00  Российская Федерация
#
#                                                    Регион  \
# Идентификатор конкурса
# 1                                      Ростовская область
# 2                                      Ростовская область
# 3                                      Ростовская область
# 4                                      Ростовская область
# 5                                      Ростовская область
# 6                                      Ростовская область
# 7                                      Ростовская область
# 8                                      Ростовская область
# 9                                      Ростовская область
# 10                      Республика Северная Осетия-Алания
# 11                      Республика Северная Осетия-Алания
# 12                                     Ростовская область
# 13                                     Ростовская область
# 14                                     Ростовская область
# 15                                     Ростовская область
#
#                              Тип населенного пункта  \
# Идентификатор конкурса
# 1                                             Город
# 2                                             Город
# 3                                             Город
# 4                                             Город
# 5                       Город федерального значения
# 6                                             Город
# 7                                             Город
# 8                                             Город
# 9                                             Город
# 10                                            Город
# 11                                            Город
# 12                                            Город
# 13                                            Город
# 14                      Город федерального значения
# 15                                            Город
#
#                        Тип документа об образовании   Изучаемый язык  \
# Идентификатор конкурса
# 1                                          Аттестат  Английский язык
# 2                                          Аттестат  Английский язык
# 3                                Диплом специалиста  Английский язык
# 4                                Диплом специалиста  Английский язык
# 5                                Диплом специалиста  Английский язык
# 6                                          Аттестат  Английский язык
# 7                                          Аттестат  Английский язык
# 8                                          Аттестат  Английский язык
# 9                                          Аттестат  Английский язык
# 10                                       Диплом СПО  Английский язык
# 11                                       Диплом СПО  Английский язык
# 12                                       Диплом СПО  Английский язык
# 13                                       Диплом СПО  Английский язык
# 14                               Диплом специалиста  Английский язык
# 15                                         Аттестат  Английский язык
#
#                                       Статус                     Направление  \
# Идентификатор конкурса
# 1                                    Принято            Управление качеством
# 2                                   Зачислен            Управление качеством
# 3                                   Зачислен                   Торговое дело
# 4                                    Принято                   Торговое дело
# 5                                   Зачислен                   Юриспруденция
# 6                                    Принято                          Сервис
# 7                       Не явился на экзамен                    Журналистика
# 8                                   Зачислен                          Сервис
# 9                       Не явился на экзамен                    Журналистика
# 10                                   Принято                   Юриспруденция
# 11                                  Зачислен                   Юриспруденция
# 12                                  Зачислен  Организация работы с молодежью
# 13                                   Принято                          Сервис
# 14                                  Зачислен                   Юриспруденция
# 15                                   Принято                          Сервис
#
#                           Форма  ...     Предмет 2 Баллы предмета 2  \
# Идентификатор конкурса           ...
# 1                       Заочная  ...  Русский язык             85.0
# 2                       Заочная  ...  Русский язык             85.0
# 3                       Заочная  ...           NaN              NaN
# 4                       Заочная  ...           NaN              NaN
# 5                       Заочная  ...  Русский язык             52.0
# 6                       Заочная  ...  Русский язык             69.0
# 7                       Заочная  ...  Русский язык             69.0
# 8                       Заочная  ...  Русский язык             69.0
# 9                       Заочная  ...  Русский язык             69.0
# 10                        Очная  ...  Русский язык             56.0
# 11                        Очная  ...  Русский язык             56.0
# 12                      Заочная  ...       История             66.0
# 13                      Заочная  ...  Русский язык             68.0
# 14                      Заочная  ...  Русский язык             48.0
# 15                        Очная  ...  Русский язык             76.0
#
#                        Тип предмета 2       Предмет 3  Баллы предмета 3  \
# Идентификатор конкурса
# 1                                 ЕГЭ          Физика              48.0
# 2                                 ЕГЭ          Физика              48.0
# 3                                 NaN             NaN               NaN
# 4                                 NaN             NaN               NaN
# 5                       Экзамены ВУЗа         История              75.0
# 6                                 ЕГЭ  Обществознание              49.0
# 7                                 ЕГЭ      Творческий             999.0
# 8                                 ЕГЭ  Обществознание              49.0
# 9                                 ЕГЭ      Творческий             999.0
# 10                      Экзамены ВУЗа         История              54.0
# 11                      Экзамены ВУЗа         История              54.0
# 12                      Экзамены ВУЗа  Обществознание              92.0
# 13                      Экзамены ВУЗа  Обществознание              92.0
# 14                      Экзамены ВУЗа         История              75.0
# 15                                ЕГЭ  Обществознание              65.0
#
#                        Тип предмета 3      Предмет 4  Баллы предмета 4  \
# Идентификатор конкурса
# 1                                 ЕГЭ            NaN               NaN
# 2                                 ЕГЭ            NaN               NaN
# 3                                 NaN            NaN               NaN
# 4                                 NaN            NaN               NaN
# 5                       Экзамены ВУЗа            NaN               NaN
# 6                                 ЕГЭ            NaN               NaN
# 7                       Экзамены ВУЗа  Собеседование               NaN
# 8                                 ЕГЭ            NaN               NaN
# 9                       Экзамены ВУЗа  Собеседование               NaN
# 10                      Экзамены ВУЗа            NaN               NaN
# 11                      Экзамены ВУЗа            NaN               NaN
# 12                      Экзамены ВУЗа            NaN               NaN
# 13                      Экзамены ВУЗа            NaN               NaN
# 14                      Экзамены ВУЗа            NaN               NaN
# 15                                ЕГЭ            NaN               NaN
#
#                        Тип предмета 4 Индивидуальные достижения
# Идентификатор конкурса
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                                 NaN                       NaN
# 4                                 NaN                       NaN
# 5                                 NaN                       NaN
# 6                                 NaN                       NaN
# 7                       Экзамены ВУЗа                       NaN
# 8                                 NaN                       NaN
# 9                       Экзамены ВУЗа                       NaN
# 10                                NaN                       NaN
# 11                                NaN                       NaN
# 12                                NaN                       NaN
# 13                                NaN                       NaN
# 14                                NaN                       NaN
# 15                                NaN                       NaN
#
# [15 rows x 26 columns]

# %%
All_group = data.groupby('Пол') # Груперовка по полю sex (пол)
Male = All_group.get_group('М') # Обращаемся к конкретной группе 
Female = All_group.get_group('Ж') # Обращаемся к конкретной группе 
# Выводим на печать количество мужчин и женщин
print ("Количество мужчин:", len(Male)) 
print ("Количество женщин:", len(Female))
# Out:
# Количество мужчин: 5808
# Количество женщин: 10743

# %%
# data.info()

# %%
# В датасете присутствуют нулевые объекты - оставляем только ненулевые
# data = data.dropna()

# %%
# Распределение подавших документы по типу населенного пункта
p_style = data.groupby('Тип населенного пункта')
u_p_style = data['Тип населенного пункта'].unique()
for one_style in u_p_style:    
    o = data[(data['Тип населенного пункта'] == one_style) & (data['Пол'] == 'М')]['Пол'].count()    
    print(one_style, o)
# Out:
# Город 4173
# Город федерального значения 36
# Населенный пункт сельского типа 1443
# Населенный пункт городского типа 156

# %%
# Выводим распределение ро типу населенного пункта
data['Тип населенного пункта'].value_counts().plot(kind='bar', label='Тип населеннго пункта', rot=90) # rot=0 - поворот подписи данных
plt.legend()
plt.title('Подача документов');

# %%
# Выводим распределение по типу Форма обучения
data['Форма'].value_counts().plot(kind='bar', label='Форма обучения', rot=0) # rot=0 - поворот подписи данных
plt.legend()
plt.title('Форма обучения');

# %%
# Группировка по полю Регион
reg_stat = data.groupby('Регион')
# Получаем уникальные значения по полю Регион - необходимо для перебора
u_reg = data['Регион'].unique()
for one_reg in u_reg:
    ab_male = data[(data['Регион'] == one_reg) & (data['Пол'] == 'М')]['Пол'].count()
    ab_fmale = data[(data['Регион'] == one_reg) & (data['Пол'] == 'Ж')]['Пол'].count()
#     print(one_reg, 'Мужчин: {}, Женщин: {}'.format(ab_male, ab_fmale))
    if (ab_male + ab_fmale) > 30:
        print(one_reg, '\tМужчины: {}, Женщины: {}, Итого: {}'.format(ab_male, ab_fmale, ab_male + ab_fmale))
# Out:
# Ростовская область 	Мужчины: 3766, Женщины: 6717, Итого: 10483
# Республика Северная Осетия-Алания 	Мужчины: 29, Женщины: 70, Итого: 99
# Краснодарский край 	Мужчины: 828, Женщины: 1947, Итого: 2775
# Волгоградская область 	Мужчины: 24, Женщины: 87, Итого: 111
# Чеченская Республика 	Мужчины: 133, Женщины: 40, Итого: 173
# Кабардино-Балкарская Республика 	Мужчины: 73, Женщины: 107, Итого: 180
# Ставропольский край 	Мужчины: 202, Женщины: 478, Итого: 680
# За пределами РФ 	Мужчины: 111, Женщины: 236, Итого: 347
# Республика Ингушетия 	Мужчины: 55, Женщины: 60, Итого: 115
# Республика Адыгея (Адыгея) 	Мужчины: 68, Женщины: 110, Итого: 178
# Республика Крым 	Мужчины: 76, Женщины: 138, Итого: 214
# Республика Калмыкия 	Мужчины: 67, Женщины: 140, Итого: 207
# Республика Дагестан 	Мужчины: 95, Женщины: 62, Итого: 157
# Ямало-Ненецкий автономный округ 	Мужчины: 15, Женщины: 16, Итого: 31
# Красноярский край 	Мужчины: 21, Женщины: 21, Итого: 42
# Карачаево-Черкесская Республика 	Мужчины: 19, Женщины: 62, Итого: 81
# Московская область 	Мужчины: 32, Женщины: 29, Итого: 61
# Астраханская область 	Мужчины: 12, Женщины: 26, Итого: 38
# Москва 	Мужчины: 19, Женщины: 18, Итого: 37
# Иркутская область 	Мужчины: 0, Женщины: 36, Итого: 36

# %%
# Распределение по регионам
data['Регион'].value_counts().plot(kind='bar', label='Рагион', rot=90) # rot=0 - поворот подписи данных
plt.legend()
plt.title('Регионы');

# %%
# Группировка по полю Направление
form_stat = data.groupby('Направление')
# Получаем уникальные значения по полю Направление - необходимо для перебора
u_form = data['Направление'].unique()
for one_form in u_form:
    zachslen = data[(data['Направление'] == one_form) & (data['Статус'] == 'Зачислен')]['Идентификатор конкурса'].count()
    priniato = data[(data['Направление'] == one_form) & (data['Статус'] == 'Принято')]['Идентификатор конкурса'].count()
    print(zachslen, '\t', priniato, '\t', one_form)
# Out:
# 29 	 54 	 Управление качеством
# 308 	 1411 	 Торговое дело
# 775 	 1456 	 Юриспруденция
# 55 	 502 	 Сервис
# 90 	 68 	 Журналистика
# 35 	 417 	 Организация работы с молодежью
# 165 	 1728 	 Менеджмент
# 46 	 260 	 Реклама и связи с общественностью
# 1122 	 2144 	 Экономика
# 98 	 185 	 Экономическая безопасность
# 54 	 63 	 Управление персоналом
# 96 	 397 	 Лингвистика
# 29 	 435 	 Информационные системы и технологии
# 32 	 292 	 Информационная безопасность
# 70 	 472 	 Прикладная информатика
# 82 	 497 	 Программная инженерия
# 9 	 26 	 Фундаментальная информатика и информационные технологии
# 55 	 330 	 Прикладная математика и информатика
# 66 	 59 	 Финансы и кредит
# 45 	 179 	 Судебная экспертиза
# 77 	 163 	 Государственное и муниципальное управление
# 19 	 78 	 Международные отношения
# 109 	 460 	 Таможенное дело
# 44 	 33 	 Товароведение
# 65 	 102 	 Зарубежное регионоведение
# 5 	 0 	 Уголовное право и криминология; уголовно-исполнительное право
# 9 	 44 	 Бизнес-информатика
# 0 	 1 	 Общая педагогика, история педагогики и образования
# 2 	 5 	 Жилищное хозяйство и коммунальная инфраструктура
# 7 	 0 	 Финансы, денежное обращение и кредит
# 1 	 0 	 Экономика и управление народным хозяйством (экономика, организация и управление предприятиями, отраслями, комплексами: АПК и сельское хозяйство)
# 6 	 1 	 Бухгалтерский учет, статистика
# 10 	 17 	 International Business (Международный бизнес)
# 6 	 0 	 Гражданское право; предпринимательское право; семейное право; международное частное право
# 3 	 0 	 Экономика и управление народным хозяйством (логистика)
# 6 	 0 	 Мировая экономика
# 5 	 0 	 Математические и инструментальные методы экономики
# 4 	 0 	 Экономика и управление народным хозяйством (маркетинг)
# 3 	 0 	 Отечественная история
# 1 	 0 	 Конституционное право; конституционный судебный процесс; муниципальное право
# 4 	 0 	 Экономика и управление народным хозяйством (менеджмент)
# 1 	 0 	 Русский язык
# 1 	 0 	 Методы и системы защиты информации, информационная безопасность
# 1 	 0 	 Экономика и управление народным хозяйством (региональная экономика)
