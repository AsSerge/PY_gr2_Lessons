# %% [markdown]
# Пример графика

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %% [markdown]
# Тот же график, но с контейнером fig

# %%
x = np.linspace(0, 10, 100)
fig = plt.figure()
plt.plot(x, np.sin(x), '.')
plt.plot(x, np.cos(x), '--')

# %% [markdown]
# Запись графика в файл

# %%
fig.savefig('my_figure.png')

# %% [markdown]
# Просмотр рисунка из файла

# %%
from IPython.display import Image
Image('my_figure.png')

# %% [markdown]
# Типы графических форматов в matplotlib

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics'}

# %% [markdown]
# Два разных графика

# %%
# Сначала создаем сетку графиков
# ax будет массивом из двух объектов Axes
fig, ax = plt.subplots(2) # Здесь задается количество выовдимых графиков
# Вызываем метод plot() соответствующего объекта
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# Визуализация функции y = f(x)
# Справка по стилям https://matplotlib.org/gallery.html#style_sheets

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import numpy as np

# %%
# %matplotlib inline
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 100)
ax.plot(x, np.sin(x))

# %% [markdown]
# Настройка цвета и стиля линий

# %%
plt.plot(x, np.sin(x - 0), color='blue') # Задаем цвет по названию
plt.plot(x, np.sin(x - 1), color='g') # Краткий код цвета (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Шкала оттенков серого цвета,
# значения в диапазоне от 0 до 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # 16-ричный код
# (RRGGBB от 00 до FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # Кортеж RGB, значения 0 и 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # Поддерживаются все названия
# цветов HTML

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted')

# %%
plt.plot(x, x + 4, linestyle='-') # сплошная линия
plt.plot(x, x + 5, linestyle='--') # штриховая линия
plt.plot(x, x + 6, linestyle='-.') # штрихпунктирная линия
plt.plot(x, x + 7, linestyle=':'); # пунктирная линия

# %%
plt.plot(x, x + 0, '-g') # сплошная линия зеленого цвета
plt.plot(x, x + 1, '--c') # штриховая линия голубого цвета
plt.plot(x, x + 2, '-.k') # штрихпунктирная линия черного цвета
plt.plot(x, x + 3, ':r'); # пунктирная линия красного цвета

# %% [markdown]
# Настройки пределов осей координат

# %%
plt.plot(x, np.sin(x))
plt.xlim(0, 10)
plt.ylim(-1.1, 1.1)
# Out:
# (-1.1, 1.1)

# %% [markdown]
# Метод plt.axis() предоставляет возможность задавать пределы осей X и Y с помощью одного вызова путем передачи списка, в котором указываются [xmin, xmax, ymin, ymax]

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5])
# Out:
# [-1, 11, -1.5, 1.5]

# %% [markdown]
# plt.axis('tight') позволяет автоматически подгонять границы к текущему графику

# %%
plt.plot(x, np.sin(x))
plt.axis('tight')
# Out:
# (-0.5, 10.5, -1.0993384025373631, 1.0996461858110391)

# %% [markdown]
# Метки на графиках

# %%
plt.plot(x, np.sin(x))
plt.title("Синусоидальная кривая") # Синусоидальная кривая
plt.xlabel("x")
plt.ylabel("sin(x)")
# Out:
# Text(0, 0.5, 'sin(x)')

# %% [markdown]
# Создание легенды

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), '-r', label='cos(x)')
plt.legend()

# %% [markdown]
# Гистограммы, разбиения по интервалам и плотность. Справка по распределениям https://docs.scipy.org/doc/numpy/reference/routines.random.html

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
data = np.random.randn(100) 
plt.hist(data, bins=15)
# Out:
# (array([ 2.,  3.,  3., 10.,  7.,  9., 12., 14.,  8., 10.,  9.,  8.,  1.,
#          2.,  2.]),
#  array([-2.05502396, -1.77927127, -1.50351857, -1.22776588, -0.95201318,
#         -0.67626048, -0.40050779, -0.12475509,  0.1509976 ,  0.4267503 ,
#          0.702503  ,  0.97825569,  1.25400839,  1.52976108,  1.80551378,
#          2.08126648]),
#  <a list of 15 Patch objects>)

# %% [markdown]
# Метод plt.axis() позволяet автоматически подгонять границы к текущему графику

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');

# %%
#  Магическая команда для того что бы графики
#  рисовались прямо в браузере:
# %matplotlib inline

#  Импортируем все необходимые библиотеки:
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

#  -------------------------------------------------
#  Задаем область определения функции:
x = np.linspace(-10, 10, 200)

#  Вычисляем область значений функции:
y = (np.abs(x / 3 - 3 / x) + x / 3 - 3 / x) / 2

#  -------------------------------------------------
#  Создаем область для графика и саму область графика:
fig, ax = plt.subplots()


#  Рисуем функцию на которую хотим посмотреть:
ax.plot(x, y)

#  Рисуем ось Y:
ax.vlines(0, y.min(), y.max(), color = 'k')
#  Рисуем ось X:
ax.hlines(0, x.min(), x.max(), color = 'k')

#  -------------------------------------------------
#  Задаем шаг основной и вспомогательной сетки:

#  Задаем шаг основных линий сетки по оси X:
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
#  Задаем шаг вспомогательных линий сетки по оси X:
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.5))
#  Задаем шаг основных линий сетки по оси Y:
ax.yaxis.set_major_locator(ticker.MultipleLocator(5))
#  Задаем шаг вспомогательных линий сетки по оси Y:
ax.yaxis.set_minor_locator(ticker.MultipleLocator(1))

#  Рисуем основную и вспомогательную сетки:
ax.minorticks_on()
#  Основная:
ax.grid(which='major', color = 'k')
#  Вспомогательная:
ax.grid(which='minor', color = 'gray', ls = ':')

#  -------------------------------------------------
#  Задаем размеры рисунка
#  Ширина:
fig.set_figwidth(12)
#  Высота:
fig.set_figheight(12)

plt.show()
